# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
orig0= pd.read_csv('OlonOlatIntersect_329547.csv')
dest0= pd.read_csv('DlonDlatIntersect_329547.csv')
od0  = pd.read_csv('Car2goOD.csv')
block0=pd.read_csv('SelectedBlock.csv')
print(orig0.shape, dest0.shape, od0.shape, block0.shape)
# Out:
# (329547, 35) (329547, 35) (329478, 14) (16773, 19)
# /Users/MacBookPro/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
orig0.columns
# Out:
# Index(['OBJECTID_1', 'FID_OlonOl', 'id', 'otime', 'dtime', 'olon', 'olat',
#        'dlon', 'dlat', 'distance', 'ofuel', 'dfuel', 'fuel_consu', 'F12',
#        'F13', 'F14', 'FID_kc_blo', 'OBJECTID', 'STATEFP10', 'COUNTYFP10',
#        'TRACTCE10', 'BLOCKCE10', 'GEOID10', 'NAME10', 'MTFCC10', 'UR10',
#        'UACE10', 'FUNCSTAT10', 'ALAND10', 'AWATER10', 'INTPTLAT10',
#        'INTPTLON10', 'TRACT_10', 'Shape_Leng', 'TRBL'],
#       dtype='object')

# %%
print(od0.columns)
od0.head()
# Out:
# Index(['id', 'otime', 'dtime', 'olon', 'olat', 'dlon', 'dlat', 'distance',
#        'ofuel', 'dfuel', 'fuel_consumption', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13'],
#       dtype='object')
#         id           otime           dtime       olon      olat       dlon  \
# 0  AXG5761  2016/1/23 0:02  2016/1/23 0:29 -122.34148  47.63633 -122.34857
# 1  ATZ5067  2016/1/23 0:02  2016/1/23 0:18 -122.30490  47.61251 -122.31481
# 2  AUK2223  2016/1/23 0:02  2016/1/23 0:27 -122.28432  47.55700 -122.35897
# 3  ATS2928  2016/1/23 0:04  2016/1/23 0:25 -122.36445  47.66644 -122.34596
# 4  AXG4702  2016/1/23 0:04  2016/1/23 0:51 -122.33523  47.57528 -122.38755
#
#        dlat  distance  ofuel  dfuel  fuel_consumption  Unnamed: 11  \
# 0  47.65491     1.326     63     63                 0          NaN
# 1  47.58820     1.742     30     30                 0          NaN
# 2  47.66690     8.355    100    100                 0          NaN
# ...

# %%
a=od0[['id', 'otime']].duplicated()

# %%
od0[a]
# Out:
# Empty DataFrame
# Columns: [id, otime, dtime, olon, olat, dlon, dlat, distance, ofuel, dfuel, fuel_consumption, Unnamed: 11, Unnamed: 12, Unnamed: 13]
# Index: []

# %%
print(block0.columns)
block0.head()
# Out:
# Index(['OBJECTID', 'STATEFP10', 'COUNTYFP10', 'TRACTCE10', 'BLOCKCE10',
#        'GEOID10', 'NAME10', 'MTFCC10', 'UR10', 'UACE10', 'FUNCSTAT10',
#        'ALAND10', 'AWATER10', 'INTPTLAT10', 'INTPTLON10', 'TRACT_10',
#        'Shape_Leng', 'Shape_Area', 'TRBL'],
#       dtype='object')
#    OBJECTID  STATEFP10  COUNTYFP10  TRACTCE10  BLOCKCE10          GEOID10  \
# 0         1         53          33       6700       1001  530330067001001
# 1         2         53          33       6900       1009  530330069001009
# 2         3         53          33      11600       3013  530330116003013
# 3         4         53          33      11600       5021  530330116005021
# 4         5         53          33      11600       5023  530330116005023
#
#        NAME10 MTFCC10  UR10  UACE10 FUNCSTAT10   ALAND10  AWATER10  \
# 0  Block 1001   G5040   NaN     NaN          S  121128.0       0.0
# 1  Block 1009   G5040   NaN     NaN          S   20412.0       0.0
# ...

# %%
plt.plot(block0.groupby('BLOCKCE10').count().OBJECTID, 'o-')
#plt.xlim(0, 100)

# %%
block0.groupby('BLOCKCE10').count().OBJECTID[50:100]
# Out:
# BLOCKCE10
# 51        1
# 52        1
# 53        1
# 54        1
# 61        1
# 62        1
# 63        1
# 64        1
# 1000    198
# 1001    199
# 1002    201
# 1003    201
# 1004    199
# 1005    199
# 1006    198
# 1007    196
# 1008    197
# 1009    192
# 1010    186
# 1011    176
# 1012    169
# 1013    166
# 1014    162
# 1015    156
# 1016    149
# 1017    140
# 1018    128
# 1019    121
# 1020    110
# 1021     99
# 1022     94
# 1023     87
# 1024     79
# 1025     67
# 1026     59
# 1027     55
# 1028     52
# 1029     47
# 1030     46
# 1031     40
# 1032     39
# 1033     38
# 1034     33
# 1035     30
# 1036     25
# 1037     25
# 1038     21
# 1039     21
# 1040     19
# 1041     18
# Name: OBJECTID, dtype: int64

# %%
orig0[['OBJECTID_1','FID_OlonOl', 'id','OBJECTID','olon', 'olat']].head(20)
# Out:
#     OBJECTID_1  FID_OlonOl       id  OBJECTID       olon      olat
# 0            1      163965  AXG5648     23211 -122.33359  47.48401
# 1            2      300778  AXG5759      5963 -122.48542  47.49611
# 2            3      153629  AXG5024     14591 -122.24179  47.49958
# 3            4      118750  AXG5473     14591 -122.24180  47.49959
# 4            5      207443  AXG5473     14591 -122.24185  47.49960
# 5            6       89665  AXG4772     14591 -122.24184  47.49960
# 6            7      290159  AXG4694     14591 -122.24178  47.49960
# 7            8       34882  AWY0057     14591 -122.24187  47.49961
# 8            9      157701  AXG5738     14591 -122.24187  47.49961
# 9           10       20503  ATZ5066     14591 -122.24186  47.49961
# 10          11      216956  AXG5492     14591 -122.24184  47.49961
# 11          12       99604  AUK2230     14591 -122.24183  47.49961
# 12          13      159065  AXG5738     14591 -122.24182  47.49961
# ...

# %%
od0.head()
# Out:
#         id           otime           dtime       olon      olat       dlon  \
# 0  AXG5761  2016/1/23 0:02  2016/1/23 0:29 -122.34148  47.63633 -122.34857
# 1  ATZ5067  2016/1/23 0:02  2016/1/23 0:18 -122.30490  47.61251 -122.31481
# 2  AUK2223  2016/1/23 0:02  2016/1/23 0:27 -122.28432  47.55700 -122.35897
# 3  ATS2928  2016/1/23 0:04  2016/1/23 0:25 -122.36445  47.66644 -122.34596
# 4  AXG4702  2016/1/23 0:04  2016/1/23 0:51 -122.33523  47.57528 -122.38755
#
#        dlat  distance  ofuel  dfuel  fuel_consumption  Unnamed: 11  \
# 0  47.65491     1.326     63     63                 0          NaN
# 1  47.58820     1.742     30     30                 0          NaN
# 2  47.66690     8.355    100    100                 0          NaN
# 3  47.70566     2.844    100    100                 0          NaN
# 4  47.68656     8.067     54     51                 3          NaN
#
#    Unnamed: 12 Unnamed: 13
# 0          NaN         NaN
# 1          NaN         NaN
# ...

# %%
block0.head()
# Out:
#    OBJECTID  STATEFP10  COUNTYFP10  TRACTCE10  BLOCKCE10          GEOID10  \
# 0         1         53          33       6700       1001  530330067001001
# 1         2         53          33       6900       1009  530330069001009
# 2         3         53          33      11600       3013  530330116003013
# 3         4         53          33      11600       5021  530330116005021
# 4         5         53          33      11600       5023  530330116005023
#
#        NAME10 MTFCC10  UR10  UACE10 FUNCSTAT10   ALAND10  AWATER10  \
# 0  Block 1001   G5040   NaN     NaN          S  121128.0       0.0
# 1  Block 1009   G5040   NaN     NaN          S   20412.0       0.0
# 2  Block 3013   G5040   NaN     NaN          S   23687.0       0.0
# 3  Block 5021   G5040   NaN     NaN          S   16082.0       0.0
# 4  Block 5023   G5040   NaN     NaN          S    2697.0       0.0
#
#    INTPTLAT10  INTPTLON10  TRACT_10  Shape_Leng    Shape_Area        TRBL
# ...

# %%
len(block.BLOCKCE10.unique())
# Out:
# 753

# %%
orig.loc[:,:'FID_kc_blo'].head()
# Out:
#    OBJECTID_1  FID_OlonOl       id      otime      dtime       olon      olat  \
# 0           1      163965  AXG5648  3/16/2016  3/16/2016 -122.33359  47.48401
# 1           2      300778  AXG5759  4/28/2016  4/28/2016 -122.48542  47.49611
# 2           3      153629  AXG5024  3/13/2016  3/13/2016 -122.24179  47.49958
# 3           4      118750  AXG5473   3/2/2016   3/2/2016 -122.24180  47.49959
# 4           5      207443  AXG5473  3/29/2016  3/29/2016 -122.24185  47.49960
#
#         dlon      dlat  distance  ofuel  dfuel  fuel_consu  F12  F13  F14  \
# 0 -122.29820  47.68821    14.204   27.0  100.0       -73.0  NaN  NaN  NaN
# 1 -122.33973  47.61295    10.563   57.0   57.0         0.0  NaN  NaN  NaN
# 2 -122.31954  47.61503     8.766   60.0   57.0         3.0  NaN  NaN  NaN
# 3 -122.33408  47.59792     8.048   69.0   66.0         3.0  NaN  NaN  NaN
# 4 -122.30889  47.57443     6.047  100.0  100.0         0.0  NaN  NaN  NaN
#
#    FID_kc_blo
# 0       23295
# 1        6064
# ...

# %%
orig_dup=orig[orig['FID_OlonOl'].duplicated()]
dest_dup=dest[dest['FID_DlonDl'].duplicated()]
orig_uniq=orig[~ orig['FID_OlonOl'].duplicated()]
dest_uniq=dest[~ dest['FID_DlonDl'].duplicated()]
print(orig_dup.shape, dest_dup.shape, orig_uniq.shape, dest_uniq.shape)
# Out:
# (74, 35) (74, 35) (329473, 35) (329473, 35)

# %%
~orig['FID_OlonOl'].duplicated()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#           ...
# 329517    True
# 329518    True
# 329519    True
# 329520    True
# 329521    True
# 329522    True
# 329523    True
# 329524    True
# 329525    True
# 329526    True
# 329527    True
# 329528    True
# 329529    True
# 329530    True
# 329531    True
# 329532    True
# 329533    True
# 329534    True
# 329535    True
# 329536    True
# 329537    True
# 329538    True
# 329539    True
# 329540    True
# 329541    True
# 329542    True
# 329543    True
# ...

# %%
block.describe()
# Out:
# /Users/MacBookPro/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#            OBJECTID  STATEFP10  COUNTYFP10      TRACTCE10     BLOCKCE10  \
# count  16773.000000    16773.0     16773.0   16773.000000  16773.000000
# mean   18078.851011       53.0        33.0   15452.435581   2438.617957
# std     9979.580386        0.0         0.0   58037.436412   1289.211592
# min        1.000000       53.0        33.0     100.000000      1.000000
# 25%     9755.000000       53.0        33.0    5400.000000   1027.000000
# 50%    18550.000000       53.0        33.0    9600.000000   2020.000000
# 75%    26377.000000       53.0        33.0   21700.000000   3023.000000
# max    35832.000000       53.0        33.0  990100.000000   7020.000000
#
#             GEOID10  UR10  UACE10       ALAND10      AWATER10    INTPTLAT10  \
# count  1.677300e+04   0.0     0.0  1.677300e+04  1.677300e+04  16773.000000
# ...
